# 14  2022-04-22T17:49:10Z  2022-04-22T18:05:30Z  2022-04-22T18:05:30Z
# 15  2022-04-22T17:50:32Z  2022-04-22T18:03:37Z  2022-04-22T18:03:37Z
# 16  2022-04-22T17:51:42Z  2022-04-22T17:54:57Z  2022-04-22T17:54:57Z
# 17  2022-04-22T17:54:52Z  2022-04-22T17:59:35Z  2022-04-22T17:59:35Z
# 18  2022-04-22T17:55:33Z  2022-04-22T18:10:23Z  2022-04-22T18:10:23Z
# 19  2022-04-22T17:55:42Z  2022-04-22T18:09:59Z  2022-04-22T18:09:59Z
#
#             duration  performance
# 0    3m45.049762343s    14.037400
# 1   27m13.062706335s    25.339700
# 2    6m27.970260098s     4.474570
# 3   16m57.577861571s   969.640000
# 4    3m39.050497734s    14.438100
# 5    5m42.079971122s     4.058900
# 6    16m29.04673943s   934.740000
# 7   13m40.650578775s     1.068240
# 8   24m26.041321363s    27.233300
# 9    6m30.040849707s     4.186600
# 10  26m49.623653449s    24.426800
# 11   17m1.063593003s   966.140000
# 12  31m24.685844533s    23.866400
# 13   12m39.05640181s    13.971200
# 14  26m37.386000688s   966.020000
# 15   24m4.803566184s     1.058150
# 16  14m32.069875492s    13.525100
# 17  18m19.059148861s     5.157920
# 18  28m26.044737449s     1.135350
# 19  23m27.166665125s     0.991592

# %%
print (df.dtypes)
# Out:
# benchmark       object
# times            int64
# nTasks           int64
# nNodes           int64
# nWorkers         int64
# Pending         object
# Running         object
# Completing      object
# Completed       object
# duration        object
# performance    float64
# dtype: object

# %%
from datetime import datetime
df['Pending'] = pd.to_datetime(df['Pending'], format='%Y-%m-%d')
df['Running'] = pd.to_datetime(df['Running'], format='%Y-%m-%d')
df['Completing'] = pd.to_datetime(df['Completing'], format='%Y-%m-%d')
df['Completed'] = pd.to_datetime(df['Completed'], format='%Y-%m-%d')
df['duration'] = pd.to_timedelta(df['duration'])

# %%
df['init'] = df['Running'] - df['Pending']
df['run'] = df['Completing'] - df['Running']
df['final'] = df['Completed'] - df['Completing']
df
# Out:
#            benchmark  times  nTasks  nNodes  nWorkers  \
# 0            hpccfft      2      16       1         1
# 1          hpccdgemm      1      16       1         1
# 2         hpccstream      0      16       1         1
# 3              nasep      3      16       1         1
# 4            hpccfft      1      16       1         1
# 5         hpccstream      3      16       1         1
# 6              nasep      2      16       1         1
# 7   hpccrandomringbw      2      16       1         1
# 8          hpccdgemm      0      16       1         1
# 9         hpccstream      2      16       1         1
# 10         hpccdgemm      2      16       1         1
# 11             nasep      1      16       1         1
# 12         hpccdgemm      3      16       1         1
# 13           hpccfft      3      16       1         1
# 14             nasep      0      16       1         1
# 15  hpccrandomringbw      1      16       1         1
# 16           hpccfft      0      16       1         1
# 17        hpccstream      1      16       1         1
# 18  hpccrandomringbw      3      16       1         1
# 19  hpccrandomringbw      0      16       1         1
#
#                      Pending                   Running  \
# 0  2022-04-22 17:27:35+00:00 2022-04-22 17:27:39+00:00
# 1  2022-04-22 17:28:17+00:00 2022-04-22 17:28:20+00:00
# 2  2022-04-22 17:30:09+00:00 2022-04-22 17:30:13+00:00
# 3  2022-04-22 17:30:51+00:00 2022-04-22 17:30:55+00:00
# 4  2022-04-22 17:31:51+00:00 2022-04-22 17:31:55+00:00
# 5  0 days 00:05:42.079971122     4.058900 0 days 00:00:04 0 days 00:04:59
# 6  0 days 00:16:29.046739430   934.740000 0 days 00:00:04 0 days 00:15:48
# 7  0 days 00:13:40.650578775     1.068240 0 days 00:00:04 0 days 00:13:04
# 8  0 days 00:24:26.041321363    27.233300 0 days 00:00:05 0 days 00:23:46
# 9  0 days 00:06:30.040849707     4.186600 0 days 00:00:03 0 days 00:05:48
# 10 0 days 00:26:49.623653449    24.426800 0 days 00:00:03 0 days 00:26:14
# 11 0 days 00:17:01.063593002   966.140000 0 days 00:00:04 0 days 00:16:18
# 12 0 days 00:31:24.685844533    23.866400 0 days 00:04:54 0 days 00:25:58
# 13 0 days 00:12:39.056401810    13.971200 0 days 00:08:49 0 days 00:03:08
# 14 0 days 00:26:37.386000688   966.020000 0 days 00:09:45 0 days 00:16:20
# 15 0 days 00:24:04.803566184     1.058150 0 days 00:10:28 0 days 00:13:05
# 16 0 days 00:14:32.069875492    13.525100 0 days 00:10:34 0 days 00:03:15
# 17 0 days 00:18:19.059148861     5.157920 0 days 00:13:01 0 days 00:04:43
# 18 0 days 00:28:26.044737449     1.135350 0 days 00:12:59 0 days 00:14:50
# 19 0 days 00:23:27.166665125     0.991592 0 days 00:08:37 0 days 00:14:17
#
#              final                     start      afterstart
# 0  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:00:00
# 1  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:00:42
# 2  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:02:34
# 3  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:03:16
# 4  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:04:16
# 5  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:04:33
# 6  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:06:26
# 7  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:07:53
# 8  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:08:19
# 9  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:09:15
# 10 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:09:46
# 11 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:10:14
# 12 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:10:53
# 13 0 days 00:00:01 2022-04-22 17:27:35+00:00 0 days 00:11:26
# 14 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:11:50
# 15 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:12:29
# 16 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:13:33
# 17 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:14:16
# 18 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:14:59
# 19 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:19:30

# %%
df['benchmark'].unique()
# Out:
# array(['hpccfft', 'hpccdgemm', 'hpccstream', 'nasep', 'hpccrandomringbw'],
#       dtype=object)

# %%
df['nWorkers'].unique()
# Out:
# array([1])

# %% [markdown]
# #  performance

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks', 'nNodes','nWorkers']

df_performance = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nWorkers in df_bench.nWorkers.unique():
            df_senario = df_bench[df_bench.nWorkers == nWorkers]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'model_time_mean' : mean(x['performance']),
                  'model_time_std' : std(x['performance']),
              })).reset_index()
            df_performance.append(df_senario)

# %%
df_performance = pd.concat(df_performance, axis=0)
df_performance
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0           hpccfft      16       1         1        10.833775        1.639560
# 0         hpccdgemm      16       4        16        37.738175        0.259058
# 0        hpccstream      16       4        16         7.200700        1.096776
# 0             nasep      16       4        16       943.542500       10.089996
# 0  hpccrandomringbw      16       1         1         1.161402        0.120155

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_performance['benchmark'].unique():
    df_bench = df_performance[(df_performance['benchmark']==model_name)] # everybenchmark
    print(df_bench)
    # plot grouped bar chart
    df_bench.plot(x='nWorkers',
                  y='model_time_mean',
                  yerr='model_time_std',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
#   benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0   hpccfft      16       1         1        10.833775         1.63956
#    benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccdgemm      16       4        16        37.738175        0.259058
#     benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccstream      16       4        16           7.2007        1.096776
#   benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0     nasep      16       4        16         943.5425       10.089996
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccrandomringbw      16       1         1         1.161402        0.120155

# %% [markdown]
# #  time slot

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks', 'nNodes','nWorkers']

df_time = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nWorkers in df_bench.nWorkers.unique():
            df_senario = df_bench[df_bench.nWorkers == nWorkers]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'init_mean' : mean(x['init'].dt.total_seconds()),
                  'init_std' : std(x['init'].dt.total_seconds()),
                'run_mean' : mean(x['run'].dt.total_seconds()),
                  'run_std' : std(x['run'].dt.total_seconds()),
                'final_mean' : mean(x['final'].dt.total_seconds()),
                  'final_std' : std(x['final'].dt.total_seconds()),
                'duration_mean' : mean(x['duration'].dt.total_seconds()),
                  'duration_std' : std(x['duration'].dt.total_seconds()),
              })).reset_index()
            df_time.append(df_senario)

# %%
df_time = pd.concat(df_time, axis=0)
df_time
# Out:
#           benchmark  nTasks  nNodes  nWorkers  init_mean    init_std  \
# 0           hpccfft      16       1         1     316.75  324.945669
# 0         hpccdgemm      16       4        16      76.25   99.265742
# 0        hpccstream      16       4        16      94.75  147.973604
# 0             nasep      16       4        16     109.50  164.918919
# 0  hpccrandomringbw      16       1         1     473.50  292.203268
#
#    run_mean     run_std  final_mean  final_std  duration_mean  duration_std
# 0    220.75   21.405315         0.0        0.0     571.777359    312.228635
# 0    983.25    5.629165         0.0        0.0    1102.311114    102.656719
# 0    218.25   39.423185         0.0        0.0     355.922949    130.235586
# 0    960.75    7.462406         0.0        0.0    1113.471885    170.757438
# 0    778.75  119.952855         0.0        0.0    1290.349972    342.553684

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_time['benchmark'].unique():
    df_bench = df_time[(df_time['benchmark']==model_name)] # everybenchmark
    df_bench['run_mean'] = df_bench['run_mean']
    df_bench['run_std'] = df_bench['run_std']

    # plot grouped bar chart
    df_bench.plot(x='nTasks',
                  y='run_mean',
                  yerr='run_std',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
# <ipython-input-420-8c915a5e4311>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-420-8c915a5e4311>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks']

df_time1 = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nTasks in df_bench.nTasks.unique():
            df_senario = df_bench[df_bench.nTasks == nTasks]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'init_sum' : sum(x['init'].dt.total_seconds()),
                'run_sum' : sum(x['run'].dt.total_seconds()),
                'final_sum' : sum(x['final'].dt.total_seconds()),
                'duration_sum' : sum(x['duration'].dt.total_seconds()),
              })).reset_index()
            df_time1.append(df_senario)

# %%
df_time1 = pd.concat(df_time1, axis=0)
df_time1
# Out:
#           benchmark  nTasks  init_sum  run_sum  final_sum  duration_sum
# 0           hpccfft      16    1267.0    883.0        0.0   2287.109438
# 0         hpccdgemm      16     305.0   3933.0        0.0   4409.244456
# 0        hpccstream      16     379.0    873.0        0.0   1423.691798
# 0             nasep      16     438.0   3843.0        0.0   4453.887539
# 0  hpccrandomringbw      16    1894.0   3115.0        0.0   5161.399888

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_time1['benchmark'].unique():
    df_bench = df_time1[(df_time1['benchmark']==model_name)] # everybenchmark
    df_bench['run_sum'] = df_bench['run_sum']

    # plot grouped bar chart
    df_bench.plot(x='nTasks',
                  y='run_sum',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
# <ipython-input-423-ef951997ad03>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## save file

# %%
scenariostr="cpumem-granularity"

# %%
df_performance['scenario']=scenariostr
df_performance
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  \
# 0           hpccfft      16       1         1        10.833775
# 0         hpccdgemm      16       4        16        37.738175
# 0        hpccstream      16       4        16         7.200700
# 0             nasep      16       4        16       943.542500
# 0  hpccrandomringbw      16       1         1         1.161402
#
#    model_time_std            scenario
# 0        1.639560  cpumem-granularity
# 0        0.259058  cpumem-granularity
# 0        1.096776  cpumem-granularity
# 0       10.089996  cpumem-granularity
# 0        0.120155  cpumem-granularity

# %%
df_time['scenario']=scenariostr
df_time
# Out:
#           benchmark  nTasks  nNodes  nWorkers  init_mean    init_std  \
# 0           hpccfft      16       1         1     316.75  324.945669
# 0         hpccdgemm      16       4        16      76.25   99.265742
# 0        hpccstream      16       4        16      94.75  147.973604
# 0             nasep      16       4        16     109.50  164.918919
# 0  hpccrandomringbw      16       1         1     473.50  292.203268
#
#    run_mean     run_std  final_mean  final_std  duration_mean  duration_std  \
# 0    220.75   21.405315         0.0        0.0     571.777359    312.228635
# 0    983.25    5.629165         0.0        0.0    1102.311114    102.656719
# 0    218.25   39.423185         0.0        0.0     355.922949    130.235586
# 0    960.75    7.462406         0.0        0.0    1113.471885    170.757438
# 0    778.75  119.952855         0.0        0.0    1290.349972    342.553684
#
#              scenario
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity

# %%
df_time1['scenario']=scenariostr
df_time1
# Out:
#           benchmark  nTasks  init_sum  run_sum  final_sum  duration_sum  \
# 0           hpccfft      16    1267.0    883.0        0.0   2287.109438
# 0         hpccdgemm      16     305.0   3933.0        0.0   4409.244456
# 0        hpccstream      16     379.0    873.0        0.0   1423.691798
# 0             nasep      16     438.0   3843.0        0.0   4453.887539
# 0  hpccrandomringbw      16    1894.0   3115.0        0.0   5161.399888
#
#              scenario
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity

# %%
app_sum=df_time1.sum()

# %%
df_time2=pd.DataFrame(data={'scenario':df_time1['scenario'].unique(), 
                            'init_sum':[app_sum.init_sum],
                            'run_sum':[app_sum.run_sum],
                            'final_sum':[app_sum.final_sum],
                             'duration_sum':[app_sum.duration_sum]})

# %%
df_time2
# Out:
#              scenario  init_sum  run_sum  final_sum  duration_sum
# 0  cpumem-granularity    4283.0  12647.0        0.0  17735.333119

# %%
df_performance.to_csv('performance.csv', mode='a', header=False, index=False)
df_time.to_csv('time.csv', mode='a', header=False, index=False)
df_time1.to_csv('timesum.csv', mode='a', header=False, index=False) 
df_time2.to_csv('appsum.csv', mode='a', header=False, index=False)

# %%
df_performance.to_csv('performance.csv', index=False)
df_time.to_csv('time.csv', index=False)
df_time1.to_csv('timesum.csv', index=False)
df_time2.to_csv('appsum.csv',  index=False)

# %% [markdown]
# # Graph

# %%
df
# Out:
#            benchmark  times  nTasks  nNodes  nWorkers  \
# 0            hpccfft      2      16       1         1
# 1          hpccdgemm      1      16       1         1
# 2         hpccstream      0      16       1         1
# 3              nasep      3      16       1         1
# 4            hpccfft      1      16       1         1
# 5         hpccstream      3      16       1         1
# 6              nasep      2      16       1         1
# 7   hpccrandomringbw      2      16       1         1
# 8          hpccdgemm      0      16       1         1
# 9         hpccstream      2      16       1         1
# 10         hpccdgemm      2      16       1         1
# 11             nasep      1      16       1         1
# 12         hpccdgemm      3      16       1         1
# 13           hpccfft      3      16       1         1
# 14             nasep      0      16       1         1
# 15  hpccrandomringbw      1      16       1         1
# 16           hpccfft      0      16       1         1
# 17        hpccstream      1      16       1         1
# 18  hpccrandomringbw      3      16       1         1
# 19  hpccrandomringbw      0      16       1         1
#
#                      Pending                   Running  \
# 0  2022-04-22 17:27:35+00:00 2022-04-22 17:27:39+00:00
# 1  0 days 00:27:13.062706335    25.339700 0 days 00:00:03 0 days 00:26:37
# 2  0 days 00:06:27.970260098     4.474570 0 days 00:00:04 0 days 00:05:51
# 3  0 days 00:16:57.577861571   969.640000 0 days 00:00:04 0 days 00:16:21
# 4  0 days 00:03:39.050497734    14.438100 0 days 00:00:04 0 days 00:03:00
# 5  0 days 00:05:42.079971122     4.058900 0 days 00:00:04 0 days 00:04:59
# 6  0 days 00:16:29.046739430   934.740000 0 days 00:00:04 0 days 00:15:48
# 7  0 days 00:13:40.650578775     1.068240 0 days 00:00:04 0 days 00:13:04
# 8  0 days 00:24:26.041321363    27.233300 0 days 00:00:05 0 days 00:23:46
# 9  0 days 00:06:30.040849707     4.186600 0 days 00:00:03 0 days 00:05:48
# 10 0 days 00:26:49.623653449    24.426800 0 days 00:00:03 0 days 00:26:14
# 11 0 days 00:17:01.063593002   966.140000 0 days 00:00:04 0 days 00:16:18
# 12 0 days 00:31:24.685844533    23.866400 0 days 00:04:54 0 days 00:25:58
# 13 0 days 00:12:39.056401810    13.971200 0 days 00:08:49 0 days 00:03:08
# 14 0 days 00:26:37.386000688   966.020000 0 days 00:09:45 0 days 00:16:20
# 15 0 days 00:24:04.803566184     1.058150 0 days 00:10:28 0 days 00:13:05
# 16 0 days 00:14:32.069875492    13.525100 0 days 00:10:34 0 days 00:03:15
# 17 0 days 00:18:19.059148861     5.157920 0 days 00:13:01 0 days 00:04:43
# 18 0 days 00:28:26.044737449     1.135350 0 days 00:12:59 0 days 00:14:50
# 19 0 days 00:23:27.166665125     0.991592 0 days 00:08:37 0 days 00:14:17
#
#              final                     start      afterstart
# 0  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:00:00
# 1  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:00:42
# 2  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:02:34
# 3  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:03:16
# 4  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:04:16
# 5  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:04:33
# 6  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:06:26
# 7  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:07:53
# 8  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:08:19
# 9  0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:09:15
# 10 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:09:46
# 11 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:10:14
# 12 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:10:53
# 13 0 days 00:00:01 2022-04-22 17:27:35+00:00 0 days 00:11:26
# 14 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:11:50
# 15 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:12:29
# 16 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:13:33
# 17 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:14:16
# 18 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:14:59
# 19 0 days 00:00:00 2022-04-22 17:27:35+00:00 0 days 00:19:30

# %%
timestamp=df.loc[18].Completed-df.loc[0].Pending
print(timestamp)
# Out:
# 0 days 00:42:04

# %%
timestamp.total_seconds()
# Out:
# 2524.0

# %%
import numpy as np
import matplotlib.pyplot as plt

color=['white','green','red','blue']

y1 = df['afterstart'].dt.total_seconds()
y2 = df['init'].dt.total_seconds()
y3 = df['run'].dt.total_seconds()
y4 = df['final'].dt.total_seconds()

labels = df['benchmark']+df['times'].map(str)

plt.barh(labels, y1, color='white', label='afterstart')
plt.barh(labels, y2, left=y1, color='green', label='init')
plt.barh(labels, y3, left=y1+y2, color='red', label='run')
plt.barh(labels, y4, left=y1+y2+y3, color='blue', label='final')
yy=y1+y2+y3
for i in yy:
    plt.axvline(x=i, color = 'b')

plt.title("Time slot")                                                        #图片标题
plt.xlabel("Time(s)")                                                              #x轴标题
plt.legend(loc=[0, 1])                                                             #图例的显示位置设置
# plt.savefig("Error Analysis.png", bbox_inches='tight')          #保存图片命令一定要放在plt.show()前面
plt.show()
