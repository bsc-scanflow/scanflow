# 12  2022-05-24T08:00:26Z  2022-05-24T08:16:31Z  2022-05-24T08:16:33Z
# 13  2022-05-24T08:03:48Z  2022-05-24T09:45:15Z  2022-05-24T09:45:16Z
# 14  2022-05-24T08:06:19Z  2022-05-24T08:25:34Z  2022-05-24T08:25:36Z
# 15  2022-05-24T08:17:26Z  2022-05-25T17:47:22Z  2022-05-25T17:47:22Z
# 16  2022-05-24T08:26:24Z  2022-05-24T08:44:14Z  2022-05-24T08:44:16Z
# 17  2022-05-24T08:45:08Z  2022-05-24T08:49:03Z  2022-05-24T08:49:05Z
# 18  2022-05-24T08:49:54Z  2022-05-24T09:06:12Z  2022-05-24T09:06:14Z
# 19  2022-05-24T09:05:58Z  2022-05-24T10:30:05Z  2022-05-24T10:30:05Z
#
#                duration  performance
# 0    34h3m19.786570241s     0.008028
# 1       17m9.215707612s    37.544500
# 2       5m15.795903139s     6.578580
# 3      23m55.275061968s  6905.340000
# 4     1h25m5.731036152s     0.355527
# 5      19m16.404508415s  8851.380000
# 6        6m4.220224293s     6.204860
# 7   33h37m25.359273539s     0.008179
# 8    1h32m59.374713962s     0.299867
# 9      20m24.628664438s    37.933300
# 10     12m43.749520711s     8.626500
# 11  33h50m53.063914244s     0.008043
# 12     29m53.137825307s    38.125400
# 13    1h58m0.441052058s     0.266072
# 14     37m57.031390178s  8453.900000
# 15   33h59m5.338164531s     0.008055
# 16     54m53.693950617s  9112.730000
# 17     58m58.989243819s    10.154400
# 18   1h15m25.208901092s    38.187400
# 19   2h34m42.412560573s     0.324656

# %%
print (df.dtypes)
# Out:
# benchmark       object
# times            int64
# nTasks           int64
# nNodes           int64
# nWorkers         int64
# Pending         object
# Running         object
# Completing      object
# Completed       object
# duration        object
# performance    float64
# dtype: object

# %%
from datetime import datetime
df['Pending'] = pd.to_datetime(df['Pending'], format='%Y-%m-%d')
df['Running'] = pd.to_datetime(df['Running'], format='%Y-%m-%d')
df['Completing'] = pd.to_datetime(df['Completing'], format='%Y-%m-%d')
df['Completed'] = pd.to_datetime(df['Completed'], format='%Y-%m-%d')
df['duration'] = pd.to_timedelta(df['duration'])

# %%
df['init'] = df['Running'] - df['Pending']
df['run'] = df['Completing'] - df['Running']
df['final'] = df['Completed'] - df['Completing']
df
# Out:
#            benchmark  times  nTasks  nNodes  nWorkers  \
# 0   hpccrandomringbw      2      16       4        16
# 1          hpccdgemm      1      16       4        16
# 2         hpccstream      0      16       4        16
# 3             minife      3      16       4        16
# 4            hpccfft      1      16       4        16
# 5             minife      2      16       4        16
# 6         hpccstream      3      16       4        16
# 7   hpccrandomringbw      0      16       4        16
# 8            hpccfft      0      16       4        16
# 9          hpccdgemm      2      16       4        16
# 10        hpccstream      2      16       4        16
# 11  hpccrandomringbw      3      16       4        16
# 12         hpccdgemm      3      16       4        16
# 13           hpccfft      3      16       4        16
# 14            minife      0      16       4        16
# 15  hpccrandomringbw      1      16       4        16
# 16            minife      1      16       4        16
# 17        hpccstream      1      16       4        16
0 days 00:00:02 2022-05-24 07:36:27+00:00 0 days 00:15:06
# 19 0 days 00:00:00 2022-05-24 07:36:27+00:00 0 days 00:19:38

# %%
df['benchmark'].unique()
# Out:
# array(['hpccrandomringbw', 'hpccdgemm', 'hpccstream', 'minife', 'hpccfft'],
#       dtype=object)

# %%
df['nWorkers'].unique()
# Out:
# array([16])

# %% [markdown]
# #  performance

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks', 'nNodes','nWorkers']

df_performance = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nWorkers in df_bench.nWorkers.unique():
            df_senario = df_bench[df_bench.nWorkers == nWorkers]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'model_time_mean' : mean(x['performance']),
                  'model_time_std' : std(x['performance']),
              })).reset_index()
            df_performance.append(df_senario)

# %%
df_performance = pd.concat(df_performance, axis=0)
df_performance
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccrandomringbw      16       4        16         0.008076        0.000060
# 0         hpccdgemm      16       4        16        37.947650        0.250904
# 0        hpccstream      16       4        16         7.891085        1.599176
# 0            minife      16       4        16      8330.837500      855.790260
# 0           hpccfft      16       4        16         0.311530        0.032827

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_performance['benchmark'].unique():
    df_bench = df_performance[(df_performance['benchmark']==model_name)] # everybenchmark
    print(df_bench)
    # plot grouped bar chart
    df_bench.plot(x='nWorkers',
                  y='model_time_mean',
                  yerr='model_time_std',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccrandomringbw      16       4        16         0.008076         0.00006
#    benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccdgemm      16       4        16         37.94765        0.250904
#     benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccstream      16       4        16         7.891085        1.599176
#   benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0    minife      16       4        16        8330.8375       855.79026
#   benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0   hpccfft      16       4        16          0.31153        0.032827

# %% [markdown]
# #  time slot

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks', 'nNodes','nWorkers']

df_time = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nWorkers in df_bench.nWorkers.unique():
            df_senario = df_bench[df_bench.nWorkers == nWorkers]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'init_mean' : mean(x['init'].dt.total_seconds()),
                  'init_std' : std(x['init'].dt.total_seconds()),
                'run_mean' : mean(x['run'].dt.total_seconds()),
                  'run_std' : std(x['run'].dt.total_seconds()),
                'final_mean' : mean(x['final'].dt.total_seconds()),
                  'final_std' : std(x['final'].dt.total_seconds()),
                'duration_mean' : mean(x['duration'].dt.total_seconds()),
                  'duration_std' : std(x['duration'].dt.total_seconds()),
              })).reset_index()
            df_time.append(df_senario)

# %%
df_time = pd.concat(df_time, axis=0)
df_time
# Out:
#           benchmark  nTasks  nNodes  nWorkers  init_mean     init_std  \
# 0  hpccrandomringbw      16       4        16     617.25   696.024200
# 0         hpccdgemm      16       4        16    1123.50  1401.820334
# 0        hpccstream      16       4        16     943.50  1351.259690
# 0            minife      16       4        16     819.00   897.931790
# 0           hpccfft      16       4        16    1291.50  1718.438608
#
#     run_mean     run_std  final_mean  final_std  duration_mean  duration_std
# 0  121300.00  742.671192        0.75   0.433013  121960.886981    592.834757
# 0     974.75    5.673403        1.25   0.829156    2143.047775   1403.677682
# 0     259.50   30.376800        1.25   0.433013    1245.688723   1335.400693
# 0    1178.75  123.420774        1.50   0.500000    2040.601228    832.821139
# 0    5427.25  427.153588        0.75   0.433013    6761.989841   1627.552889

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_time['benchmark'].unique():
    df_bench = df_time[(df_time['benchmark']==model_name)] # everybenchmark
    df_bench['run_mean'] = df_bench['run_mean']
    df_bench['run_std'] = df_bench['run_std']

    # plot grouped bar chart
    df_bench.plot(x='nTasks',
                  y='run_mean',
                  yerr='run_std',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
# <ipython-input-14-8c915a5e4311>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-14-8c915a5e4311>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks']

df_time1 = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nTasks in df_bench.nTasks.unique():
            df_senario = df_bench[df_bench.nTasks == nTasks]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'init_sum' : sum(x['init'].dt.total_seconds()),
                'run_sum' : sum(x['run'].dt.total_seconds()),
                'final_sum' : sum(x['final'].dt.total_seconds()),
                'duration_sum' : sum(x['duration'].dt.total_seconds()),
              })).reset_index()
            df_time1.append(df_senario)

# %%
df_time1 = pd.concat(df_time1, axis=0)
df_time1
# Out:
#           benchmark  nTasks  init_sum   run_sum  final_sum   duration_sum
# 0  hpccrandomringbw      16    2469.0  485200.0        3.0  487843.547923
# 0         hpccdgemm      16    4494.0    3899.0        5.0    8572.191098
# 0        hpccstream      16    3774.0    1038.0        5.0    4982.754892
# 0            minife      16    3276.0    4715.0        6.0    8162.404911
# 0           hpccfft      16    5166.0   21709.0        3.0   27047.959363

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_time1['benchmark'].unique():
    df_bench = df_time1[(df_time1['benchmark']==model_name)] # everybenchmark
    df_bench['run_sum'] = df_bench['run_sum']

    # plot grouped bar chart
    df_bench.plot(x='nTasks',
                  y='run_sum',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
# <ipython-input-17-ef951997ad03>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## save file

# %%
scenariostr="volcano"

# %%
df_performance['scenario']=scenariostr
df_performance
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  \
# 0  hpccrandomringbw      16       4        16         0.008076
# 0         hpccdgemm      16       4        16        37.947650
# 0        hpccstream      16       4        16         7.891085
# 0            minife      16       4        16      8330.837500
# 0           hpccfft      16       4        16         0.311530
#
#    model_time_std scenario
# 0        0.000060  volcano
# 0        0.250904  volcano
# 0        1.599176  volcano
# 0      855.790260  volcano
# 0        0.032827  volcano

# %%
df_time['scenario']=scenariostr
df_time
# Out:
#           benchmark  nTasks  nNodes  nWorkers  init_mean     init_std  \
# 0  hpccrandomringbw      16       4        16     617.25   696.024200
# 0         hpccdgemm      16       4        16    1123.50  1401.820334
# 0        hpccstream      16       4        16     943.50  1351.259690
# 0            minife      16       4        16     819.00   897.931790
# 0           hpccfft      16       4        16    1291.50  1718.438608
#
#     run_mean     run_std  final_mean  final_std  duration_mean  duration_std  \
# 0  121300.00  742.671192        0.75   0.433013  121960.886981    592.834757
# 0     974.75    5.673403        1.25   0.829156    2143.047775   1403.677682
# 0     259.50   30.376800        1.25   0.433013    1245.688723   1335.400693
# 0    1178.75  123.420774        1.50   0.500000    2040.601228    832.821139
# 0    5427.25  427.153588        0.75   0.433013    6761.989841   1627.552889
#
#   scenario
# 0  volcano
# 0  volcano
# 0  volcano
# 0  volcano
# 0  volcano

# %%
df_time1['scenario']=scenariostr
df_time1
# Out:
#           benchmark  nTasks  init_sum   run_sum  final_sum   duration_sum  \
# 0  hpccrandomringbw      16    2469.0  485200.0        3.0  487843.547923
# 0         hpccdgemm      16    4494.0    3899.0        5.0    8572.191098
# 0        hpccstream      16    3774.0    1038.0        5.0    4982.754892
# 0            minife      16    3276.0    4715.0        6.0    8162.404911
# 0           hpccfft      16    5166.0   21709.0        3.0   27047.959363
#
#   scenario
# 0  volcano
# 0  volcano
# 0  volcano
# 0  volcano
# 0  volcano

# %%
app_sum=df_time1.sum()

# %%
df_time2=pd.DataFrame(data={'scenario':df_time1['scenario'].unique(), 
                            'init_sum':[app_sum.init_sum],
                            'run_sum':[app_sum.run_sum],
                            'final_sum':[app_sum.final_sum],
                             'duration_sum':[app_sum.duration_sum]})

# %%
df_time2
# Out:
#   scenario  init_sum   run_sum  final_sum   duration_sum
# 0  volcano   19179.0  516561.0       22.0  536608.858187

# %%
df_performance.to_csv('performance.csv', mode='a', header=False, index=False)
df_time.to_csv('time.csv', mode='a', header=False, index=False)
df_time1.to_csv('timesum.csv', mode='a', header=False, index=False) 
df_time2.to_csv('appsum.csv', mode='a', header=False, index=False)

# %%
df_performance.to_csv('performance.csv', index=False)
df_time.to_csv('time.csv', index=False)
df_time1.to_csv('timesum.csv', index=False)
df_time2.to_csv('appsum.csv',  index=False)

# %% [markdown]
# # Graph

# %%
df
# Out:
#            benchmark  times  nTasks  nNodes  nWorkers  \
# 0   hpccrandomringbw      2      16       4        16
# 1          hpccdgemm      1      16       4        16
# 2         hpccstream      0      16       4        16
# 3             minife      3      16       4        16
# 4            hpccfft      1      16       4        16
# 5             minife      2      16       4        16
# 6         hpccstream      3      16       4        16
# 7   hpccrandomringbw      0      16       4        16
# 8            hpccfft      0      16       4        16
# 9          hpccdgemm      2      16       4        16
# 10        hpccstream      2      16       4        16
# 11  hpccrandomringbw      3      16       4        16
# 12         hpccdgemm      3      16       4        16
# 13           hpccfft      3      16       4        16
# 14            minife      0      16       4        16
# 15  hpccrandomringbw      1      16       4        16
# 16            minife      1      16       4        16
# 17        hpccstream      1      16       4        16
# 18         hpccdgemm      0      16       4        16
# 19           hpccfft      2      16       4        16
#
#                      Pending                   Running  \
# 0  2022-05-24 07:36:27+00:00 2022-05-24 07:36:35+00:00
# 1  2022-05-24 07:37:09+00:00 2022-05-24 07:37:18+00:00
# 2  2022-05-24 07:39:02+00:00 2022-05-24 07:39:11+00:00
# 3  2022-05-24 07:39:43+00:00 2022-05-24 07:39:53+00:00
# 4  2022-05-24 07:40:43+00:00 2022-05-24 07:40:54+00:00
# 5  2022-05-24 07:41:01+00:00 2022-05-24 07:41:11+00:00
# 6  2022-05-24 07:42:54+00:00 2022-05-24 07:43:07+00:00
# 7  2022-05-24 07:44:22+00:00 2022-05-24 07:44:32+00:00
# 8  2022-05-24 07:44:48+00:00 2022-05-24 07:45:00+00:00
# 9  2022-05-24 07:45:44+00:00 2022-05-24 07:49:06+00:00
# 10 2022-05-24 07:46:16+00:00 2022-05-24 07:54:29+00:00
# 11 2022-05-24 07:46:44+00:00 2022-05-24 07:59:11+00:00
# 12 2022-05-24 07:47:24+00:00 2022-05-24 08:00:26+00:00
# 13 2022-05-24 07:47:58+00:00 2022-05-24 08:03:48+00:00
# 10 0 days 00:12:43.749520711     8.626500 0 days 00:08:13 0 days 00:03:49
# 11 1 days 09:50:53.063914243     0.008043 0 days 00:12:27 1 days 09:37:40
# 12 0 days 00:29:53.137825307    38.125400 0 days 00:13:02 0 days 00:16:05
# 13 0 days 01:58:00.441052058     0.266072 0 days 00:15:50 0 days 01:41:27
# 14 0 days 00:37:57.031390177  8453.900000 0 days 00:17:57 0 days 00:19:15
# 15 1 days 09:59:05.338164531     0.008055 0 days 00:28:24 1 days 09:29:56
# 16 0 days 00:54:53.693950617  9112.730000 0 days 00:36:19 0 days 00:17:50
# 17 0 days 00:58:58.989243819    10.154400 0 days 00:54:19 0 days 00:03:55
# 18 0 days 01:15:25.208901092    38.187400 0 days 00:58:21 0 days 00:16:18
# 19 0 days 02:34:42.412560573     0.324656 0 days 01:09:53 0 days 01:24:07
#
#              final                     start      afterstart
# 0  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:00:00
# 1  0 days 00:00:00 2022-05-24 07:36:27+00:00 0 days 00:00:42
# 2  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:02:35
# 3  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:03:16
# 4  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:04:16
# 5  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:04:34
# 6  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:06:27
# 7  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:07:55
# 8  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:08:21
# 9  0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:09:17
# 10 0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:09:49
# 11 0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:10:17
# 12 0 days 00:00:02 2022-05-24 07:36:27+00:00 0 days 00:10:57
# 13 0 days 00:00:01 2022-05-24 07:36:27+00:00 0 days 00:11:31
# 14 0 days 00:00:02 2022-05-24 07:36:27+00:00 0 days 00:11:55
# 15 0 days 00:00:00 2022-05-24 07:36:27+00:00 0 days 00:12:35
# 16 0 days 00:00:02 2022-05-24 07:36:27+00:00 0 days 00:13:38
# 17 0 days 00:00:02 2022-05-24 07:36:27+00:00 0 days 00:14:22
# 18 0 days 00:00:02 2022-05-24 07:36:27+00:00 0 days 00:15:06
# 19 0 days 00:00:00 2022-05-24 07:36:27+00:00 0 days 00:19:38

# %%
df.to_csv('full-volcano.csv', index=False)

# %%
timestamp=df.loc[15].Completed-df.loc[0].Pending
print(timestamp)
# Out:
# 1 days 10:10:55

# %%
timestamp.total_seconds()
# Out:
# 123055.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 14}) # 改变所有字体大小，改变其他性质类似

color=['white','green','red','blue']

y1 = df['afterstart'].dt.total_seconds()
y2 = df['init'].dt.total_seconds()
y3 = df['run'].dt.total_seconds()
y4 = df['final'].dt.total_seconds()

labels = df['benchmark']+df['times'].map(str)

# plt.barh(labels, y1, color='white')
# plt.barh(labels, y2, left=y1, color='green', label='pending')
# plt.barh(labels, y3, left=y1+y2, color='red', label='running')
# plt.barh(labels, y4, left=y1+y2+y3, color='blue', label='completing')
# plt.barh(labels, color='white')
plt.barh(labels, y2, color='green', label='pending')
plt.barh(labels, y3, left=y2, color='red', label='running')
plt.barh(labels, y4, left=y2+y3, color='blue', label='completing')
yy=y1+y2+y3
for i in yy:
    if i> 2000:
        plt.axvline(x=i, color = 'b')

plt.xlim((0,130000)) 
plt.title("Time slot")                                                        #图片标题
plt.xlabel("Time(s)")                                                              #x轴标题
plt.legend(loc=[-0.2, -0.30], ncol=3)  
# plt.savefig("Error Analysis.png", bbox_inches='tight')          #保存图片命令一定要放在plt.show()前面
# plt.show()
plt.savefig('app-granularity.pdf',bbox_inches='tight',pad_inches=0.1)
