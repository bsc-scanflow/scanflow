# 14  2022-04-28T15:48:13Z  2022-04-28T16:03:59Z  2022-04-28T16:03:59Z
# 15  2022-04-28T15:54:09Z  2022-04-28T16:01:38Z  2022-04-28T16:01:38Z
# 16  2022-04-28T15:51:53Z  2022-04-28T16:07:42Z  2022-04-28T16:07:43Z
# 17  2022-04-28T15:54:04Z  2022-04-28T15:57:01Z  2022-04-28T15:57:01Z
# 18  2022-04-28T15:55:24Z  2022-04-28T16:11:18Z  2022-04-28T16:11:19Z
# 19  2022-04-28T15:55:25Z  2022-04-28T15:59:22Z  2022-04-28T15:59:22Z
#
#             duration  performance
# 0    7m51.808766123s      1.90254
# 1    17m9.874659816s     37.73530
# 2    3m46.878242517s      8.04033
# 3   16m45.888582077s     36.67000
# 4    4m35.826770165s      9.38925
# 5   16m48.919251759s     36.59000
# 6    3m55.842850901s      7.74851
# 7    7m49.970403287s      1.88612
# 8    4m41.836154565s      9.42602
# 9   17m58.419961024s     35.70320
# 10   4m25.884049557s      7.78914
# 11  10m47.827672187s      1.88057
# 12  17m49.619091748s     35.78170
# 13   8m44.822207503s     10.61650
# 14  18m50.855527049s     36.95000
# 15  15m46.564563683s      1.82910
# 16  20m58.863325228s     36.88000
# 17     9m35.8766212s      8.15407
# 18   23m2.868830224s     38.89780
# 19   6m40.828130262s      9.39895

# %%
print (df.dtypes)
# Out:
# benchmark       object
# times            int64
# nTasks           int64
# nNodes           int64
# nWorkers         int64
# Pending         object
# Running         object
# Completing      object
# Completed       object
# duration        object
# performance    float64
# dtype: object

# %%
from datetime import datetime
df['Pending'] = pd.to_datetime(df['Pending'], format='%Y-%m-%d')
df['Running'] = pd.to_datetime(df['Running'], format='%Y-%m-%d')
df['Completing'] = pd.to_datetime(df['Completing'], format='%Y-%m-%d')
df['Completed'] = pd.to_datetime(df['Completed'], format='%Y-%m-%d')
df['duration'] = pd.to_timedelta(df['duration'])

# %%
df['init'] = df['Running'] - df['Pending']
df['run'] = df['Completing'] - df['Running']
df['final'] = df['Completed'] - df['Completing']
df
# Out:
#            benchmark  times  nTasks  nNodes  nWorkers  \
# 0   hpccrandomringbw      2      16       1         1
# 1          hpccdgemm      1      16       4        16
# 2         hpccstream      0      16       4        16
# 3              nasep      3      16       4        16
# 4            hpccfft      1      16       1         1
# 5              nasep      2      16       4        16
# 6         hpccstream      3      16       4        16
# 7   hpccrandomringbw      0      16       1         1
# 8            hpccfft      0      16       1         1
# 9          hpccdgemm      2      16       4        16
# 10        hpccstream      2      16       4        16
# 11  hpccrandomringbw      3      16       1         1
# 12         hpccdgemm      3      16       4        16
# 13           hpccfft      3      16       1         1
# 14             nasep      0      16       4        16
# 15  hpccrandomringbw      1      16       1         1
# 16             nasep      1      16       4        16
# 17        hpccstream      1      16       4        16
# 18         hpccdgemm      0      16       4        16
# 19           hpccfft      2      16       1         1
#
#                      Pending                   Running  \
# 0  2022-04-28 15:33:54+00:00 2022-04-28 15:33:58+00:00
# 1  2022-04-28 15:34:36+00:00 2022-04-28 15:34:44+00:00
# 2  2022-04-28 15:36:29+00:00 2022-04-28 15:36:36+00:00
# 3  2022-04-28 15:37:10+00:00 2022-04-28 15:37:17+00:00
# 4  2022-04-28 15:38:10+00:00 2022-04-28 15:38:13+00:00
# 7  0 days 00:07:49.970403287      1.88612 0 days 00:00:04 0 days 00:07:13
# 8  0 days 00:04:41.836154565      9.42602 0 days 00:00:03 0 days 00:03:56
# 9  0 days 00:17:58.419961024     35.70320 0 days 00:00:13 0 days 00:17:01
# 10 0 days 00:04:25.884049557      7.78914 0 days 00:00:42 0 days 00:03:03
# 11 0 days 00:10:47.827672187      1.88057 0 days 00:02:50 0 days 00:07:16
# 12 0 days 00:17:49.619091748     35.78170 0 days 00:00:13 0 days 00:16:55
# 13 0 days 00:08:44.822207503     10.61650 0 days 00:04:19 0 days 00:03:48
# 14 0 days 00:18:50.855527049     36.95000 0 days 00:02:28 0 days 00:15:46
# 15 0 days 00:15:46.564563683      1.82910 0 days 00:07:45 0 days 00:07:29
# 16 0 days 00:20:58.863325228     36.88000 0 days 00:04:26 0 days 00:15:49
# 17 0 days 00:09:35.876621200      8.15407 0 days 00:05:54 0 days 00:02:57
# 18 0 days 00:23:02.868830224     38.89780 0 days 00:06:31 0 days 00:15:54
# 19 0 days 00:06:40.828130262      9.39895 0 days 00:02:00 0 days 00:03:57
#
#              final                     start      afterstart
# 0  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:00:00
# 1  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:00:42
# 2  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:02:35
# 3  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:03:16
# 4  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:04:16
# 5  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:04:33
# 6  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:06:26
# 7  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:07:54
# 8  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:08:20
# 9  0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:09:15
# 10 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:09:46
# 11 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:10:14
# 12 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:10:53
# 13 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:11:27
# 14 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:11:51
# 15 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:12:30
# 16 0 days 00:00:01 2022-04-28 15:33:54+00:00 0 days 00:13:33
# 17 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:14:16
# 18 0 days 00:00:01 2022-04-28 15:33:54+00:00 0 days 00:14:59
# 19 0 days 00:00:00 2022-04-28 15:33:54+00:00 0 days 00:19:31

# %%
df['benchmark'].unique()
# Out:
# array(['hpccrandomringbw', 'hpccdgemm', 'hpccstream', 'nasep', 'hpccfft'],
#       dtype=object)

# %%
df['nWorkers'].unique()
# Out:
# array([ 1, 16])

# %% [markdown]
# #  performance

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks', 'nNodes','nWorkers']

df_performance = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nWorkers in df_bench.nWorkers.unique():
            df_senario = df_bench[df_bench.nWorkers == nWorkers]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'model_time_mean' : mean(x['performance']),
                  'model_time_std' : std(x['performance']),
              })).reset_index()
            df_performance.append(df_senario)

# %%
df_performance = pd.concat(df_performance, axis=0)
df_performance
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccrandomringbw      16       1         1         1.874583        0.027474
# 0         hpccdgemm      16       4        16        37.029500        1.351367
# 0        hpccstream      16       4        16         7.933013        0.169650
# 0             nasep      16       4        16        36.772500        0.147373
# 0           hpccfft      16       1         1         9.707680        0.524880

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_performance['benchmark'].unique():
    df_bench = df_performance[(df_performance['benchmark']==model_name)] # everybenchmark
    print(df_bench)
    # plot grouped bar chart
    df_bench.plot(x='nWorkers',
                  y='model_time_mean',
                  yerr='model_time_std',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccrandomringbw      16       1         1         1.874583        0.027474
#    benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccdgemm      16       4        16          37.0295        1.351367
#     benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0  hpccstream      16       4        16         7.933013         0.16965
#   benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0     nasep      16       4        16          36.7725        0.147373
#   benchmark  nTasks  nNodes  nWorkers  model_time_mean  model_time_std
# 0   hpccfft      16       1         1          9.70768         0.52488

# %% [markdown]
# #  time slot

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks', 'nNodes','nWorkers']

df_time = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nWorkers in df_bench.nWorkers.unique():
            df_senario = df_bench[df_bench.nWorkers == nWorkers]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'init_mean' : mean(x['init'].dt.total_seconds()),
                  'init_std' : std(x['init'].dt.total_seconds()),
                'run_mean' : mean(x['run'].dt.total_seconds()),
                  'run_std' : std(x['run'].dt.total_seconds()),
                'final_mean' : mean(x['final'].dt.total_seconds()),
                  'final_std' : std(x['final'].dt.total_seconds()),
                'duration_mean' : mean(x['duration'].dt.total_seconds()),
                  'duration_std' : std(x['duration'].dt.total_seconds()),
              })).reset_index()
            df_time.append(df_senario)

# %%
df_time = pd.concat(df_time, axis=0)
df_time
# Out:
#           benchmark  nTasks  nNodes  nWorkers  init_mean    init_std  \
# 0  hpccrandomringbw      16       1         1     160.75  188.278218
# 0         hpccdgemm      16       4        16     106.25  164.413161
# 0        hpccstream      16       4        16     102.50  145.904935
# 0             nasep      16       4        16     107.00  108.353588
# 0           hpccfft      16       1         1      96.25  105.407246
#
#    run_mean    run_std  final_mean  final_std  duration_mean  duration_std
# 0     437.0   7.245688        0.00   0.000000     634.042851    194.357601
# 0     993.0  26.972208        0.25   0.433013    1140.195636    141.296036
# 0     181.0   2.738613        0.00   0.000000     326.120441    144.918623
# 0     952.5   5.123475        0.25   0.433013    1101.131672    104.087894
# 0     234.5   3.774917        0.00   0.000000     370.828316    101.930130

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_time['benchmark'].unique():
    df_bench = df_time[(df_time['benchmark']==model_name)] # everybenchmark
    df_bench['run_mean'] = df_bench['run_mean']
    df_bench['run_std'] = df_bench['run_std']

    # plot grouped bar chart
    df_bench.plot(x='nTasks',
                  y='run_mean',
                  yerr='run_std',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
# <ipython-input-160-8c915a5e4311>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-160-8c915a5e4311>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from numpy import percentile, mean, std

l_gb = ['benchmark', 'nTasks']

df_time1 = []

for model_name in df['benchmark'].unique():
       df_bench = df[(df['benchmark']==model_name)] # everybenchmark
       for nTasks in df_bench.nTasks.unique():
            df_senario = df_bench[df_bench.nTasks == nTasks]
            df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
                  'init_sum' : sum(x['init'].dt.total_seconds()),
                'run_sum' : sum(x['run'].dt.total_seconds()),
                'final_sum' : sum(x['final'].dt.total_seconds()),
                'duration_sum' : sum(x['duration'].dt.total_seconds()),
              })).reset_index()
            df_time1.append(df_senario)

# %%
df_time1 = pd.concat(df_time1, axis=0)
df_time1
# Out:
#           benchmark  nTasks  init_sum  run_sum  final_sum  duration_sum
# 0  hpccrandomringbw      16     643.0   1748.0        0.0   2536.171405
# 0         hpccdgemm      16     425.0   3972.0        1.0   4560.782543
# 0        hpccstream      16     410.0    724.0        0.0   1304.481764
# 0             nasep      16     428.0   3810.0        1.0   4404.526686
# 0           hpccfft      16     385.0    938.0        0.0   1483.313262

# %%
import matplotlib.pyplot as plt
import pandas as pd

for model_name in df_time1['benchmark'].unique():
    df_bench = df_time1[(df_time1['benchmark']==model_name)] # everybenchmark
    df_bench['run_sum'] = df_bench['run_sum']

    # plot grouped bar chart
    df_bench.plot(x='nTasks',
                  y='run_sum',
                    kind='bar',
                    stacked=False,
                    title=f"Grouped Bar Graph {model_name}")
# Out:
# <ipython-input-163-ef951997ad03>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## save file

# %%
scenariostr="cpumem-granularity"

# %%
df_performance['scenario']=scenariostr
df_performance
# Out:
#           benchmark  nTasks  nNodes  nWorkers  model_time_mean  \
# 0  hpccrandomringbw      16       1         1         1.874583
# 0         hpccdgemm      16       4        16        37.029500
# 0        hpccstream      16       4        16         7.933013
# 0             nasep      16       4        16        36.772500
# 0           hpccfft      16       1         1         9.707680
#
#    model_time_std            scenario
# 0        0.027474  cpumem-granularity
# 0        1.351367  cpumem-granularity
# 0        0.169650  cpumem-granularity
# 0        0.147373  cpumem-granularity
# 0        0.524880  cpumem-granularity

# %%
df_time['scenario']=scenariostr
df_time
# Out:
#           benchmark  nTasks  nNodes  nWorkers  init_mean    init_std  \
# 0  hpccrandomringbw      16       1         1     160.75  188.278218
# 0         hpccdgemm      16       4        16     106.25  164.413161
# 0        hpccstream      16       4        16     102.50  145.904935
# 0             nasep      16       4        16     107.00  108.353588
# 0           hpccfft      16       1         1      96.25  105.407246
#
#    run_mean    run_std  final_mean  final_std  duration_mean  duration_std  \
# 0     437.0   7.245688        0.00   0.000000     634.042851    194.357601
# 0     993.0  26.972208        0.25   0.433013    1140.195636    141.296036
# 0     181.0   2.738613        0.00   0.000000     326.120441    144.918623
# 0     952.5   5.123475        0.25   0.433013    1101.131672    104.087894
# 0     234.5   3.774917        0.00   0.000000     370.828316    101.930130
#
#              scenario
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity

# %%
df_time1['scenario']=scenariostr
df_time1
# Out:
#           benchmark  nTasks  init_sum  run_sum  final_sum  duration_sum  \
# 0  hpccrandomringbw      16     643.0   1748.0        0.0   2536.171405
# 0         hpccdgemm      16     425.0   3972.0        1.0   4560.782543
# 0        hpccstream      16     410.0    724.0        0.0   1304.481764
# 0             nasep      16     428.0   3810.0        1.0   4404.526686
# 0           hpccfft      16     385.0    938.0        0.0   1483.313262
#
#              scenario
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity
# 0  cpumem-granularity

# %%
app_sum=df_time1.sum()

# %%
df_time2=pd.DataFrame(data={'scenario':df_time1['scenario'].unique(), 
                            'init_sum':[app_sum.init_sum],
                            'run_sum':[app_sum.run_sum],
                            'final_sum':[app_sum.final_sum],
                             'duration_sum':[app_sum.duration_sum]})

# %%
df_time2
# Out:
#              scenario  init_sum  run_sum  final_sum  duration_sum
# 0  cpumem-granularity    2291.0  11192.0        2.0  14289.275661

# %%
df_performance.to_csv('performance.csv', mode='a', header=False, index=False)
df_time.to_csv('time.csv', mode='a', header=False, index=False)
df_time1.to_csv('timesum.csv', mode='a', header=False, index=False) 
df_time2.to_csv('appsum.csv', mode='a', header=False, index=False)

# %%
df_performance.to_csv('performance.csv', index=False)
df_time.to_csv('time.csv', index=False)
df_time1.to_csv('timesum.csv', index=False)
df_time2.to_csv('appsum.csv',  index=False)

# %% [markdown]
# # Graph

# %%
df
# Out:
#            benchmark  times  nTasks  nNodes  nWorkers  \
# 0   hpccrandomringbw      2      16       1         1
# 1          hpccdgemm      1      16       4         4
# 2         hpccstream      0      16       4         4
# 3              nasep      3      16       4         4
# 4            hpccfft      1      16       1         1
# 5              nasep      2      16       4         4
# 6         hpccstream      3      16       4         4
# 7   hpccrandomringbw      0      16       1         1
# 8            hpccfft      0      16       1         1
# 9          hpccdgemm      2      16       4         4
# 10        hpccstream      2      16       4         4
# 11  hpccrandomringbw      3      16       1         1
# 12         hpccdgemm      3      16       4         4
# 13           hpccfft      3      16       1         1
# 14             nasep      0      16       4         4
# 15  hpccrandomringbw      1      16       1         1
# 16             nasep      1      16       4         4
# 17        hpccstream      1      16       4         4
# 18         hpccdgemm      0      16       4         4
# 19           hpccfft      2      16       1         1
#
#                      Pending                   Running  \
# 0  2022-04-28 16:44:45+00:00 2022-04-28 16:44:49+00:00
# 1  2022-04-28 16:45:27+00:00 2022-04-28 16:45:32+00:00
# 3  0 days 00:16:55.811766486     35.90000 0 days 00:00:05 0 days 00:16:09
# 4  0 days 00:04:34.828498205      9.47127 0 days 00:00:03 0 days 00:03:55
# 5  0 days 00:16:47.819775934     36.12000 0 days 00:00:04 0 days 00:16:05
# 6  0 days 00:03:44.815196556      7.71347 0 days 00:00:04 0 days 00:03:05
# 7  0 days 00:07:52.587006799      1.87813 0 days 00:00:04 0 days 00:07:16
# 8  0 days 00:04:31.818245248     10.64180 0 days 00:00:04 0 days 00:03:45
# 9  0 days 00:18:51.271417160     33.37750 0 days 00:00:04 0 days 00:18:13
# 10 0 days 00:04:14.817866309      7.69585 0 days 00:00:27 0 days 00:03:05
# 11 0 days 00:10:46.809936456      1.83083 0 days 00:02:39 0 days 00:07:28
# 12 0 days 00:18:47.835838828     33.75020 0 days 00:00:04 0 days 00:18:02
# 13 0 days 00:09:04.826206415      9.35610 0 days 00:04:22 0 days 00:04:00
# 14 0 days 00:19:00.816921761     36.03000 0 days 00:02:12 0 days 00:16:08
# 15 0 days 00:16:31.826189575      1.88096 0 days 00:08:34 0 days 00:07:18
# 16 0 days 00:22:57.861534629     36.30000 0 days 00:06:21 0 days 00:15:59
# 17 0 days 00:09:44.822390951      8.09811 0 days 00:05:57 0 days 00:03:07
# 18 0 days 00:26:21.811157406     33.64740 0 days 00:06:25 0 days 00:19:22
# 19 0 days 00:06:10.804206859     11.50090 0 days 00:01:54 0 days 00:03:40
#
#              final                     start      afterstart
# 0  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:00:00
# 1  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:00:42
# 2  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:02:34
# 3  0 days 00:00:01 2022-04-28 16:44:45+00:00 0 days 00:03:15
# 4  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:04:16
# 5  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:04:33
# 6  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:06:26
# 7  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:07:53
# 8  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:08:19
# 9  0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:09:15
# 10 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:09:46
# 11 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:10:14
# 12 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:10:53
# 13 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:11:26
# 14 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:11:50
# 15 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:12:29
# 16 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:13:33
# 17 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:14:16
# 18 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:14:59
# 19 0 days 00:00:00 2022-04-28 16:44:45+00:00 0 days 00:19:30

# %%
timestamp=df.loc[18].Completed-df.loc[0].Pending
print(timestamp)
# Out:
# 0 days 00:37:25

# %%
timestamp.total_seconds()
# Out:
# 2245.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 14}) # 改变所有字体大小，改变其他性质类似

color=['white','green','red','blue']

y1 = df['afterstart'].dt.total_seconds()
y2 = df['init'].dt.total_seconds()
y3 = df['run'].dt.total_seconds()
y4 = df['final'].dt.total_seconds()

labels = df['benchmark']+df['times'].map(str)

plt.barh(labels, y1, color='white')
plt.barh(labels, y2, left=y1, color='green', label='pending')
plt.barh(labels, y3, left=y1+y2, color='red', label='running')
plt.barh(labels, y4, left=y1+y2+y3, color='blue', label='completing')
yy=y1+y2+y3
for i in yy:
    if i> 2200:
        plt.axvline(x=i, color = 'b')

plt.xlim((0,3000)) 
plt.title("Time slot")                                                        #图片标题
plt.xlabel("Time(s)")                                                              #x轴标题
plt.legend(loc=[-0.2, -0.30], ncol=3)  
# plt.savefig("Error Analysis.png", bbox_inches='tight')          #保存图片命令一定要放在plt.show()前面
# plt.show()
plt.savefig('app-granularity.pdf',bbox_inches='tight',pad_inches=0.1)
